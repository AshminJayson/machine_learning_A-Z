# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Position_Salaries.csv')
x = df.iloc[: , 1:-1].values
y = df.iloc[:, -1].values

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=3)

regressor.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=3)

# %%
y_pred = regressor.predict(x)

# %%
compare = np.concatenate((y_pred.reshape(len(y_pred), 1), y.reshape(len(y), 1)), axis = 1)
compare
# Out:
# array([[  46666.66666667,   45000.        ],
#        [  50000.        ,   50000.        ],
#        [  60000.        ,   60000.        ],
#        [  73333.33333333,   80000.        ],
#        [ 113333.33333333,  110000.        ],
#        [ 150000.        ,  150000.        ],
#        [ 166666.66666667,  200000.        ],
#        [ 266666.66666667,  300000.        ],
#        [ 555555.55555556,  500000.        ],
#        [ 555555.55555556,  600000.        ],
#        [ 855555.55555556, 1000000.        ]])

# %%
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')

# %%
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape(len(x_grid), 1)

plt.scatter(x, y)
plt.title('Position Salaries Random Forest Regressor')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.plot(x_grid, regressor.predict(x_grid), color='red')
# Out:
# C:\Users\ashmi\AppData\Local\Temp\ipykernel_7340\3451555146.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.1)
